# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
import os 
import pandas as pd

dat = pd.read_csv('Leinhardt.csv')
dat.head()
# Out:
#   Unnamed: 0  income  infant    region oil
# 0  Australia    3426    26.7      Asia  no
# 1    Austria    3350    23.7    Europe  no
# 2    Belgium    3346    17.0    Europe  no
# 3     Canada    4751    16.8  Americas  no
# 4    Denmark    5029    13.5    Europe  no

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
sns.set(rc={'figure.figsize':(19.7,8.27)})
sns.heatmap(dat.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.distplot(dat["income"])
# Out:
# <Axes: xlabel='income', ylabel='Density'>

# %%
sns.scatterplot(x='income',y='infant',data=dat)
# Out:
# <Axes: xlabel='income', ylabel='infant'>

# %%
dat["region"] = pd.Categorical(dat["region"])

# %%
sns.countplot(x=dat["region"], order=["Asia", "Europe", "Africa", "Americas"])
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
dat["oil"] = pd.Categorical(dat["oil"])

# %%
sns.countplot(x=dat["oil"])
# Out:
# <Axes: xlabel='oil', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.catplot(x="income", y="infant", data=dat);
plt.ioff()
